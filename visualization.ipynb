# %%
# %matplotlib inline
from visualize import *

# %%
mbie_10 = read_all('mbie_eb_100-0.100000.txt', prefix='final/')
mbie_20 = read_all('mbie_eb_100-0.200000.txt', prefix='final/')
mbie_50 = read_all('mbie_eb_100-0.500000.txt', prefix='final/')
mbie_75 = read_all('mbie_eb_100-0.750000.txt', prefix='final/')
mbie_100 = read_all('mbie_eb_100-1.000000.txt', prefix='final/')

# %%
draw_mean([mbie_10, mbie_20, mbie_50, mbie_75, mbie_100], 
          ['mbie-0.1', 'mbie-0.2', 'mbie-0.5', 'mbie-0.75', 'mbie-1.0'],
          optimal=5 * 0.99 ** 99, title='MBIE 100 States')

# %%
ubev_1 = read_all('ubev_eb_100-0.100000-0.010000.txt', prefix='final/')
ubev_5 = read_all('ubev_eb_100-0.100000-0.050000.txt', prefix='final/')
ubev_10 = read_all('ubev_eb_100-0.100000-0.100000.txt', prefix='final/')
ubev_25 = read_all('ubev_eb_100-0.100000-0.250000.txt', prefix='final/')
ubev_35 = read_all('ubev_eb_100-0.100000-0.350000.txt', prefix='final/')
ubev_50 = read_all('ubev_eb_100-0.100000-0.500000.txt', prefix='final/')
ubev_75 = read_all('ubev_eb_100-0.100000-0.750000.txt', prefix='final/')
ubev_100 = read_all('ubev_eb_100-0.100000-1.000000.txt', prefix='final/')

# %%
draw_mean([ubev_1, ubev_5, ubev_10, ubev_25, ubev_35, ubev_50, ubev_75, ubev_100], 
          ['ubev-0.01', 'ubev-0.05', 'ubev-0.1', 'ubev-0.25', 'ubev-0.35', 'ubev-0.5', 'ubev-0.75', 'ubev-1.0'], 
          optimal=5 * 0.99 ** 99,  title='UBEV 100 States')

# %%
draw_mean([ubev_25, ubev_50, mbie_50, mbie_75], 
          ['ubev-0.25', 'ubev-0.5', 'mbie-0.5', 'mbie-0.75'], 
          optimal=5 * 0.99 ** 99,  title='100 States')

# %%
mbie_10 = read_all('mbie_eb_200-0.100000.txt', prefix='final/200/')
mbie_20 = read_all('mbie_eb_200-0.200000.txt', prefix='final/200/')
mbie_50 = read_all('mbie_eb_200-0.500000.txt', prefix='final/200/')
mbie_75 = read_all('mbie_eb_200-0.750000.txt', prefix='final/200/')
mbie_100 = read_all('mbie_eb_200-1.000000.txt', prefix='final/200/')

# %%
draw_mean([mbie_10, mbie_20, mbie_50, mbie_75, mbie_100], 
          ['mbie-0.1', 'mbie-0.2', 'mbie-0.5', 'mbie-0.75', 'mbie-1.0'],
          optimal=5 * 0.995 ** 199, title='MBIE 200 States')

# %%
ubev_1 = read_all('ubev_eb_200-0.100000-0.010000.txt', prefix='final/200/')
ubev_5 = read_all('ubev_eb_200-0.100000-0.050000.txt', prefix='final/200/')
ubev_10 = read_all('ubev_eb_200-0.100000-0.100000.txt', prefix='final/200/')
ubev_25 = read_all('ubev_eb_200-0.100000-0.250000.txt', prefix='final/200/')
ubev_50 = read_all('ubev_eb_200-0.100000-0.500000.txt', prefix='final/200/')
ubev_100 = read_all('ubev_eb_200-0.100000-1.000000.txt', prefix='final/200/')

# %%
draw_mean([ubev_1, ubev_5, ubev_10, ubev_25, ubev_50, ubev_100], 
          ['ubev-0.01', 'ubev-0.05', 'ubev-0.1', 'ubev-0.25', 'ubev-0.5', 'ubev-1.0'],
          optimal=5 * 0.99 ** 99,  title='UBEV 200 States')

# %%
draw_mean([mbie_10, mbie_20, ubev_1, ubev_5, ubev_10, ubev_25], 
          ['mbie-0.1', 'mbie-0.2', 'ubev-0.01', 'ubev-0.05', 'ubev-0.1', 'ubev-0.25'],
          optimal=5 * 0.995 ** 199, title='200 States')
