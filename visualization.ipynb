# %%
# %matplotlib inline
from visualize import *

# %%
PREFIX = 'cmake-build-release/'
ubev_1 = get_rewards('ubev_eb_100-0.100000-0.010000.txt', prefix=PREFIX)
ubev_5 = get_rewards('ubev_eb_100-0.100000-0.050000.txt', prefix=PREFIX)
ubev_10 = get_rewards('ubev_eb_100-0.100000-0.100000.txt', prefix=PREFIX)
ubev_20 = get_rewards('ubev_eb_100-0.100000-0.200000.txt', prefix=PREFIX)
ubev_50 = get_rewards('ubev_eb_100-0.100000-0.500000.txt', prefix=PREFIX)
ubev_80 = get_rewards('ubev_eb_100-0.100000-0.800000.txt', prefix=PREFIX)
ubev_100 = get_rewards('ubev_eb_100-0.100000-1.000000.txt', prefix=PREFIX)

# %%
draw([ubev_1, ubev_5, ubev_10, ubev_20, ubev_50, ubev_80, ubev_100], 
     [0.01, 0.05, 0.10, 0.20, 0.50, 0.80, 1.00])

# %%
PREFIX = 'cmake-build-release/'
mbie_1 = get_rewards('mbie_eb_100-0.100000.txt', prefix=PREFIX)
mbie_2 = get_rewards('mbie_eb_100-0.200000.txt', prefix=PREFIX)
mbie_5 = get_rewards('mbie_eb_100-0.500000.txt', prefix=PREFIX)
mbie_10 = get_rewards('mbie_eb_100-1.000000.txt', prefix=PREFIX)
mbie_20 = get_rewards('mbie_eb_100-2.000000.txt', prefix=PREFIX)

# %%
draw([mbie_1, mbie_2, mbie_5, mbie_10, mbie_20], 
     [0.1, 0.2, 0.5, 1.0, 2.0])

# %%
draw([ubev_1, ubev_10, ubev_20, mbie_5, mbie_10], ['ubev_0.01', 'ubev_0.1', 'ubev_0.2', 'mbie_0.5', 'mbie_1.0'])

# %%
ubev_1 = get_rewards('ubev_eb_50-0.100000-0.010000.txt', prefix=PREFIX)
ubev_5 = get_rewards('ubev_eb_50-0.100000-0.050000.txt', prefix=PREFIX)
ubev_10 = get_rewards('ubev_eb_50-0.100000-0.100000.txt', prefix=PREFIX)
ubev_20 = get_rewards('ubev_eb_50-0.100000-0.200000.txt', prefix=PREFIX)
ubev_50 = get_rewards('ubev_eb_50-0.100000-0.500000.txt', prefix=PREFIX)
ubev_80 = get_rewards('ubev_eb_50-0.100000-0.800000.txt', prefix=PREFIX)
ubev_100 = get_rewards('ubev_eb_50-0.100000-1.000000.txt', prefix=PREFIX)

# %%
draw([ubev_1, ubev_5, ubev_10, ubev_20, ubev_50, ubev_80, ubev_100], 
     [0.01, 0.05, 0.10, 0.20, 0.50, 0.80, 1.00])

# %%
PREFIX = 'cmake-build-release/'
mbie_1 = get_rewards('mbie_eb_50-0.100000.txt', prefix=PREFIX)
mbie_2 = get_rewards('mbie_eb_50-0.200000.txt', prefix=PREFIX)
mbie_5 = get_rewards('mbie_eb_50-0.500000.txt', prefix=PREFIX)
mbie_10 = get_rewards('mbie_eb_50-1.000000.txt', prefix=PREFIX)
mbie_20 = get_rewards('mbie_eb_50-2.000000.txt', prefix=PREFIX)

# %%
draw([mbie_1, mbie_2, mbie_5, mbie_10, mbie_20], 
     [0.1, 0.2, 0.5, 1.0, 2.0])

# %%
draw([ubev_10, ubev_20, mbie_5, mbie_10], ['ubev_0.1', 'ubev_0.2', 'mbie_0.5', 'mbie_1.0'])
